# %% [markdown]
# # MyRecommenderVsContextual
#
# A/B experiment analysis

# %%
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

pd.set_option("display.precision", 3)

# %matplotlib inline

# %%
experiment = "RECOMMENDERS"

# %%
data = pd.read_json("./log/data.json", lines=True)
data["treatment"] = data["experiments"].map(lambda experiments: experiments[experiment])

# %%
data.head()
# Out:
#   message               timestamp  user  track  time    latency  \
# 0    next 2023-04-12 21:45:43.867  3255   2659  1.00  2.125e-03
# 1    next 2023-04-12 21:45:43.878  3255   7585  1.00  4.058e-04
# 2    next 2023-04-12 21:45:43.886  3255   1592  1.00  3.800e-04
# 3    next 2023-04-12 21:45:43.893  3255   3300  0.99  4.530e-04
# 4    next 2023-04-12 21:45:43.901  3255    159  1.00  3.386e-04
#
#    recommendation             experiments treatment
# 0          7585.0  {'RECOMMENDERS': 'T6'}        T6
# 1          1592.0  {'RECOMMENDERS': 'T6'}        T6
# 2          3300.0  {'RECOMMENDERS': 'T6'}        T6
# 3           159.0  {'RECOMMENDERS': 'T6'}        T6
# 4          4205.0  {'RECOMMENDERS': 'T6'}        T6

# %% [markdown]
# ## Visualize sessions

# %%
Session = namedtuple("Session", ["timestamp", "tracks", "time", "latency"])

def sessionize(user_data):
    sessions = []
    session = None
    for _, row in user_data.sort_values("timestamp").iterrows():
        if session is None:
            session = Session(row["timestamp"], 0, 0, 0)
        
        session = session._replace(
            tracks = session.tracks + 1, 
            time = session.time + row["time"],
            latency = session.latency + row["latency"] * 1000,
        )
        
        if row["message"] == "last":
            sessions.append(session._asdict())
            session = None
    return sessions

# %%
sessions = (
    data
    .groupby(["user", "treatment"])
    .apply(sessionize)
    .explode()
    .apply(pd.Series)
)

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %% [markdown]
# ## Analyze the experiment

# %%
user_level_data = (
  sessions
    .reset_index()
    .groupby(["user", "treatment"])
    .agg(
        {
            "timestamp": "count",
            "tracks": "sum",
            "time": "sum",
            "latency": "sum"
        }
    )
)

user_level_data["sessions"] = user_level_data["timestamp"]
user_level_data["mean_request_latency"] = user_level_data["latency"] / user_level_data["tracks"]
user_level_data["mean_tracks_per_session"] = user_level_data["tracks"] / user_level_data["sessions"]
user_level_data["mean_time_per_session"] = user_level_data["time"] / user_level_data["sessions"]

metrics = [
    "time", 
    "sessions", 
    "mean_request_latency", 
    "mean_tracks_per_session", 
    "mean_time_per_session"
]

user_level_metrics = user_level_data[metrics].copy().reset_index()

# %%
treatment_level_metrics = (
    user_level_metrics
    .groupby("treatment")[metrics]
    .agg(["count", "mean", "var"])
)

# %%
def dof(n_0, n_1, s2_0, s2_1):
    numerator = (s2_0 / n_0 + s2_1 / n_1) * (s2_0 / n_0 + s2_1 / n_1)
    denominator = s2_0 * s2_0 / n_0 / n_0 / (n_0 - 1) + s2_1 * s2_1 / n_1 / n_1 / (n_1 - 1)
    return numerator / denominator


def ci(n_0, n_1, s2_0, s2_1, alpha=0.05):
    return ss.t.ppf(1 - alpha/2, dof(n_0, n_1, s2_0, s2_1)) * np.sqrt(s2_0 / n_0 + s2_1 / n_1)


effects = []

control = [data for treatment, data in treatment_level_metrics.iterrows() if treatment == "C"][0]

for treatment, row in treatment_level_metrics.iterrows():
    if treatment == "C":
        continue
    
    for metric in metrics:
        control_mean = control[metric]["mean"]
        treatment_mean = row[metric]["mean"]
        
        effect = treatment_mean - control_mean
        conf_int = ci(
            control[metric]["count"],
            row[metric]["count"],
            control[metric]["var"],
            row[metric]["var"],
        )
        effects.append({
            "treatment": treatment,
            "metric": metric,
            "control_mean": control_mean,
            "treatment_mean": treatment_mean,
            "effect": effect / control_mean * 100,
            "lower": (effect - conf_int) / control_mean * 100,
            "upper": (effect + conf_int) / control_mean * 100,
            "significant": (effect + conf_int) * (effect - conf_int) > 0
        })

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=False)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_dd909_row0_col2, #T_dd909_row0_col3, #T_dd909_row0_col4, #T_dd909_row1_col2, #T_dd909_row1_col3, #T_dd909_row1_col4, #T_dd909_row2_col2, #T_dd909_row2_col3, #T_dd909_row2_col4, #T_dd909_row3_col2, #T_dd909_row3_col3, #T_dd909_row3_col4, #T_dd909_row4_col2, #T_dd909_row4_col3, #T_dd909_row4_col4, #T_dd909_row5_col2, #T_dd909_row5_col3, #T_dd909_row5_col4, #T_dd909_row6_col2, #T_dd909_row6_col3, #T_dd909_row6_col4, #T_dd909_row7_col3, #T_dd909_row8_col3, #T_dd909_row9_col3, #T_dd909_row10_col2, #T_dd909_row10_col3, #T_dd909_row11_col2, #T_dd909_row11_col3, #T_dd909_row12_col2, #T_dd909_row12_col3, #T_dd909_row13_col2, #T_dd909_row13_col3, #T_dd909_row14_col2, #T_dd909_row14_col3, #T_dd909_row14_col4, #T_dd909_row15_col2, #T_dd909_row15_col3, #T_dd909_row15_col4, #T_dd909_row16_col2, #T_dd909_row16_col3, #T_dd909_row16_col4, #T_dd909_row17_col2, #T_dd909_row17_col3, #T_dd909_row17_col4, #T_dd909_row18_col2, #T_dd909_row18_col3, #T_dd909_row18_col4, #T_dd909_row19_col2, #T_dd909_row19_col3, #T_dd909_row19_col4, #T_dd909_row20_col2, #T_dd909_row20_col3, #T_dd909_row20_col4, #T_dd909_row21_col2, #T_dd909_row21_col3, #T_dd909_row21_col4, #T_dd909_row22_col2, #T_dd909_row22_col3, #T_dd909_row22_col4, #T_dd909_row23_col2, #T_dd909_row23_col3, #T_dd909_row23_col4, #T_dd909_row24_col2, #T_dd909_row24_col3, #T_dd909_row24_col4, #T_dd909_row25_col2, #T_dd909_row25_col3, #T_dd909_row25_col4, #T_dd909_row26_col2, #T_dd909_row26_col3, #T_dd909_row26_col4, #T_dd909_row27_col2, #T_dd909_row27_col3, #T_dd909_row27_col4, #T_dd909_row28_col2, #T_dd909_row28_col3, #T_dd909_row28_col4, #T_dd909_row29_col2, #T_dd909_row29_col3, #T_dd909_row29_col4, #T_dd909_row30_col2, #T_dd909_row30_col3, #T_dd909_row30_col4, #T_dd909_row31_col2, #T_dd909_row31_col3, #T_dd909_row31_col4, #T_dd909_row32_col2, #T_dd909_row32_col3, #T_dd909_row32_col4, #T_dd909_row34_col2, #T_dd909_row34_col3, #T_dd909_row34_col4 {
#   color: green;
# }
# #T_dd909_row0_col7, #T_dd909_row1_col7, #T_dd909_row2_col7, #T_dd909_row3_col7, #T_dd909_row4_col7, #T_dd909_row5_col7, #T_dd909_row6_col7, #T_dd909_row14_col7, #T_dd909_row15_col7, #T_dd909_row16_col7, #T_dd909_row17_col7, #T_dd909_row18_col7, #T_dd909_row19_col7, #T_dd909_row20_col7, #T_dd909_row21_col7, #T_dd909_row22_col7, #T_dd909_row23_col7, #T_dd909_row24_col7, #T_dd909_row25_col7, #T_dd909_row26_col7, #T_dd909_row27_col7, #T_dd909_row28_col7, #T_dd909_row29_col7, #T_dd909_row30_col7, #T_dd909_row31_col7, #T_dd909_row32_col7, #T_dd909_row33_col7, #T_dd909_row34_col7 {
#   color: white;
#   background-color: green;
# }
# #T_dd909_row7_col2, #T_dd909_row7_col4, #T_dd909_row8_col2, #T_dd909_row8_col4, #T_dd909_row9_col2, #T_dd909_row9_col4, #T_dd909_row10_col4, #T_dd909_row11_col4, #T_dd909_row12_col4, #T_dd909_row13_col4, #T_dd909_row33_col2, #T_dd909_row33_col3, #T_dd909_row33_col4 {
#   color: red;
# }
# #T_dd909_row7_col7, #T_dd909_row8_col7, #T_dd909_row9_col7, #T_dd909_row10_col7, #T_dd909_row11_col7, #T_dd909_row12_col7, #T_dd909_row13_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_dd909_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd909_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_dd909_row0_col0" class="data row0 col0" >T7</td>
#       <td id="T_dd909_row0_col1" class="data row0 col1" >time</td>
#       <td id="T_dd909_row0_col2" class="data row0 col2" >127.584</td>
#       <td id="T_dd909_row0_col3" class="data row0 col3" >153.074</td>
#       <td id="T_dd909_row0_col4" class="data row0 col4" >102.094</td>
#       <td id="T_dd909_row0_col5" class="data row0 col5" >2.875</td>
#       <td id="T_dd909_row0_col6" class="data row0 col6" >6.544</td>
#       <td id="T_dd909_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row1" class="row_heading level0 row1" >25</th>
#       <td id="T_dd909_row1_col0" class="data row1 col0" >T6</td>
#       <td id="T_dd909_row1_col1" class="data row1 col1" >time</td>
#       <td id="T_dd909_row1_col2" class="data row1 col2" >101.307</td>
#       <td id="T_dd909_row1_col3" class="data row1 col3" >120.253</td>
#       <td id="T_dd909_row1_col4" class="data row1 col4" >82.361</td>
#       <td id="T_dd909_row1_col5" class="data row1 col5" >2.875</td>
#       <td id="T_dd909_row1_col6" class="data row1 col6" >5.788</td>
#       <td id="T_dd909_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_dd909_row2_col0" class="data row2 col0" >T5</td>
#       <td id="T_dd909_row2_col1" class="data row2 col1" >time</td>
#       <td id="T_dd909_row2_col2" class="data row2 col2" >137.442</td>
#       <td id="T_dd909_row2_col3" class="data row2 col3" >157.986</td>
#       <td id="T_dd909_row2_col4" class="data row2 col4" >116.897</td>
#       <td id="T_dd909_row2_col5" class="data row2 col5" >2.875</td>
#       <td id="T_dd909_row2_col6" class="data row2 col6" >6.827</td>
#       <td id="T_dd909_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_dd909_row3_col0" class="data row3 col0" >T4</td>
#       <td id="T_dd909_row3_col1" class="data row3 col1" >time</td>
#       <td id="T_dd909_row3_col2" class="data row3 col2" >81.265</td>
#       <td id="T_dd909_row3_col3" class="data row3 col3" >101.293</td>
#       <td id="T_dd909_row3_col4" class="data row3 col4" >61.237</td>
#       <td id="T_dd909_row3_col5" class="data row3 col5" >2.875</td>
#       <td id="T_dd909_row3_col6" class="data row3 col6" >5.212</td>
#       <td id="T_dd909_row3_col7" class="data row3 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_dd909_row4_col0" class="data row4 col0" >T3</td>
#       <td id="T_dd909_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_dd909_row4_col2" class="data row4 col2" >30.017</td>
#       <td id="T_dd909_row4_col3" class="data row4 col3" >41.873</td>
#       <td id="T_dd909_row4_col4" class="data row4 col4" >18.160</td>
#       <td id="T_dd909_row4_col5" class="data row4 col5" >2.875</td>
#       <td id="T_dd909_row4_col6" class="data row4 col6" >3.739</td>
#       <td id="T_dd909_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd909_row5_col0" class="data row5 col0" >T2</td>
#       <td id="T_dd909_row5_col1" class="data row5 col1" >time</td>
#       <td id="T_dd909_row5_col2" class="data row5 col2" >76.537</td>
#       <td id="T_dd909_row5_col3" class="data row5 col3" >93.157</td>
#       <td id="T_dd909_row5_col4" class="data row5 col4" >59.918</td>
#       <td id="T_dd909_row5_col5" class="data row5 col5" >2.875</td>
#       <td id="T_dd909_row5_col6" class="data row5 col6" >5.076</td>
#       <td id="T_dd909_row5_col7" class="data row5 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd909_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_dd909_row6_col0" class="data row6 col0" >T1</td>
#       <td id="T_dd909_row6_col1" class="data row6 col1" >time</td>
#       <td id="T_dd909_row6_col2" class="data row6 col2" >53.649</td>
#       <td id="T_dd909_row6_col3" class="data row6 col3" >64.266</td>
#       <td id="T_dd909_row6_col4" class="data row6 col4" >43.031</td>
#       <td id="T_dd909_row6_col5" class="data row6 col5" >2.875</td>
#       <td id="T_dd909_row6_col6" class="data
